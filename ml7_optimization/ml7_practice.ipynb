# %% [markdown]
# # ML-7. Оптимизация гиперпараметров модели. Практика

# %%
#импорт библиотек
import numpy as np #для матричных вычислений
import pandas as pd #для анализа и предобработки данных
import matplotlib.pyplot as plt #для визуализации
import seaborn as sns #для визуализации

from sklearn import linear_model #линейные моделиё
from sklearn import tree #деревья решений
from sklearn import ensemble #ансамбли
from sklearn import metrics #метрики
from sklearn import preprocessing #предобработка
from sklearn.model_selection import train_test_split #сплитование выборки

# %% [markdown]
# ## Подготовка

# %%
data = pd.read_csv('data/_train_sem09 (1).csv')
data.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# 1      0      1      0
# 2      0      0      0
# 3      0      0      0
# 4      0      0      0
#
# [5 rows x 1777 columns]

# %%
X = data.drop(['Activity'], axis=1)
y = data['Activity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state = 42, test_size = 0.2)

# %% [markdown]
# ## 1.1 GridSearchCV + LogisticRegression

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
              {'penalty': ['l2', 'none'] , # тип регуляризации
              'solver': ['lbfgs', 'sag'], # алгоритм оптимизации
               'C': [0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 1]}, # уровень силы регурялизации
              
              {'penalty': ['l1', 'l2'] ,
              'solver': ['liblinear', 'saga'],
               'C': [0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 1]}
]

grid_search = GridSearchCV(
    estimator=linear_model.LogisticRegression(
        random_state=42, #генератор случайных чисел
        max_iter=50 #количество итераций на сходимость
    ), 
    param_grid=param_grid, 
    cv=5, # кросс-валидация (количество фолдов)
    n_jobs = -1
)  
# %time grid_search.fit(X_train, y_train) 
print("accuracy на тестовом наборе: {:.2f}".format(grid_search.score(X_test, y_test)))
y_test_pred = grid_search.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(grid_search.best_params_))
# Out:
# CPU times: total: 3.38 s
# Wall time: 45.1 s
# accuracy на тестовом наборе: 0.76
# f1_score на тестовом наборе: 0.79
# Наилучшие значения гиперпараметров: {'C': 0.3, 'penalty': 'l1', 'solver': 'saga'}
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# ## 1.2 GridSearchCV + DecisionTreeClassifier

# %%
param_grid = {'min_samples_leaf': list(np.linspace(5, 100, 25, dtype=int)),
              'max_depth': list(np.linspace(1, 30, 15, dtype=int)),
              'criterion':['entropy','gini']
              }
            
random_search_tree = GridSearchCV(
    estimator=tree.DecisionTreeClassifier(random_state=42), 
    param_grid=param_grid, 
    cv=5, # кросс-валидация (количество фолдов)
    n_jobs = -1
)  
# %time random_search_tree.fit(X_train, y_train) 
print("accuracy на тестовом наборе: {:.2f}".format(random_search_tree.score(X_test, y_test)))
y_test_pred = random_search_tree.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(random_search_tree.best_params_))
# Out:
# CPU times: total: 5.58 s
# Wall time: 2min 30s
# accuracy на тестовом наборе: 0.73
# f1_score на тестовом наборе: 0.76
# Наилучшие значения гиперпараметров: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 68}

# %% [markdown]
# ## 2.1 RandomizedSearchCV + LogisticRegression

# %%
from sklearn.model_selection import RandomizedSearchCV

#np.linspace(start(от), stop(до), num=50(количество),dtype- тип данных)
param_distributions = {'penalty': ['l2', 'none'] ,
                       'solver': ['lbfgs', 'sag'],
                       'C': list(np.linspace(0.01, 1, 10, dtype=float))
                       }
            
random_search = RandomizedSearchCV(
    estimator=linear_model.LogisticRegression(random_state=42, max_iter=50), 
    param_distributions=param_distributions, 
    cv=5, # кросс-валидация (количество фолдов)
    n_iter = 50, 
    n_jobs = -1
)  
# %time random_search.fit(X_train, y_train) 
print("accuracy на тестовом наборе: {:.2f}".format(random_search.score(X_test, y_test)))
y_test_pred = random_search.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(random_search.best_params_))
# Out:
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 40 is smaller than n_iter=50. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# CPU times: total: 2.19 s
# Wall time: 29.6 s
# accuracy на тестовом наборе: 0.75
# f1_score на тестовом наборе: 0.78
# Наилучшие значения гиперпараметров: {'solver': 'sag', 'penalty': 'l2', 'C': 0.01}
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# ## 2.2 RandomizedSearchCV + DecisionTreeClassifier

# %%
param_distributions = {'min_samples_leaf': list(np.linspace(5, 100, 25, dtype=int)),
                       'max_depth': list(np.linspace(1, 30, 15, dtype=int)),
                       'criterion':['entropy','gini']
                       }
            
random_search_tree = RandomizedSearchCV(
    estimator=tree.DecisionTreeClassifier(random_state=42), 
    param_distributions=param_distributions, 
    cv=5, # кросс-валидация (количество фолдов)
    n_iter = 50, 
    n_jobs = -1
)  
# %time random_search_tree.fit(X_train, y_train) 
print("accuracy на тестовом наборе: {:.2f}".format(random_search_tree.score(X_test, y_test)))
y_test_pred = random_search_tree.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
print("Наилучшие значения гиперпараметров: {}".format(random_search_tree.best_params_))
# Out:
# CPU times: total: 672 ms
# Wall time: 11 s
# accuracy на тестовом наборе: 0.73
# f1_score на тестовом наборе: 0.76
# Наилучшие значения гиперпараметров: {'min_samples_leaf': 68, 'max_depth': 3, 'criterion': 'gini'}

# %% [markdown]
# ## 3.1 hyperopt + LogisticRegression

# %%
#делаем импорт и выведем версию библиотеки
from sklearn.model_selection import cross_val_score
import hyperopt
from hyperopt import hp, fmin, tpe, Trials

# %%
# зададим пространство поиска гиперпараметров
penalty_list = ['l2', 'none']
solver_list = ['lbfgs', 'sag']
c_list = list(np.linspace(0.01, 1, 10, dtype=float))
space = {'penalty': hp.choice('penalty', penalty_list) , # тип регуляризации
         'solver': hp.choice('solver', solver_list), # алгоритм оптимизации
         #'C': hp.quniform('C', 0.01, 1, 0.1)
         'C': hp.choice('C', c_list)
         } # уровень силы регурялизации

# %%
# зафксируем random_state
random_state = 42
def hyperopt_rf(params, cv=5, X=X_train, y=y_train, random_state=random_state): 
    # функция получает комбинацию гиперпараметров в "params"
    params = {'penalty': str(params['penalty']), 
              'solver': str(params['solver']), 
              'C': float(params['C'])
              }    
    
    # используем эту комбинацию для построения модели
    #model = ensemble.RandomForestClassifier(**params, random_state=random_state)
    model = linear_model.LogisticRegression(**params, random_state=42, max_iter=50)

    # обучаем модель
    model.fit(X, y)
    #score = metrics.f1_score(y, model.predict(X))
    
    # обучать модель можно также с помощью кросс-валидации
    # применим  cross validation с тем же количеством фолдов
    score = cross_val_score(model, X, y, cv=cv, scoring="f1", n_jobs=-1).mean()

    # метрику необходимо минимизировать, поэтому ставим знак минус
    return -score

# %%
# начинаем подбор гиперпараметров
# %time

trials = Trials() # используется для логирования результатов

best=fmin(hyperopt_rf, # наша функция 
          space=space, # пространство гиперпараметров
          algo=tpe.suggest, # алгоритм оптимизации, установлен по умолчанию, задавать необязательно
          max_evals=50, # максимальное количество итераций
          trials=trials, # логирование результатов
          #rstate=np.random.RandomState(random_state)# фиксируем для повторяемости результата
          rstate=np.random.default_rng(random_state),
          verbose=False
         )
print("Наилучшие значения гиперпараметров penalty = {}, solver = {}, C = {}".format(penalty_list[best['penalty']], solver_list[best['solver']], c_list[best['C']]))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Наилучшие значения гиперпараметров penalty = l2, solver = sag, C = 0.01

# %%
# рассчитаем точность для тестовой выборки
model = linear_model.LogisticRegression(C=float(c_list[best['C']]),
    penalty=str(penalty_list[best['penalty']]),
    solver=str(solver_list[best['solver']]), 
    random_state=42, max_iter=50)

model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
print("accuracy на тестовом наборе: {:.2f}".format(model.score(X_test, y_test)))
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# f1_score на обучающем наборе: 0.82
# accuracy на тестовом наборе: 0.75
# f1_score на тестовом наборе: 0.78
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# ## 3.2 hyperopt + DecisionTreeClassifier

# %%
# зададим пространство поиска гиперпараметров
criterion_list = ['entropy','gini']
space={'max_depth' : hp.quniform('max_depth', 1, 30, 2),
       'min_samples_leaf': hp.quniform('min_samples_leaf', 5, 100, 3),
       'criterion': hp.choice('criterion', criterion_list)
      }

# %%
# зафксируем random_state
random_state = 42
def hyperopt_rf(params, cv=5, X=X_train, y=y_train, random_state=random_state):
    # функция получает комбинацию гиперпараметров в "params"
    params = {'max_depth': int(params['max_depth']), 
              'min_samples_leaf': int(params['min_samples_leaf']),
              'criterion': str(params['criterion'])
              }
  
    # используем эту комбинацию для построения модели
    model = tree.DecisionTreeClassifier(**params, random_state=random_state)

    # обучаем модель
    model.fit(X, y)
    #score = metrics.f1_score(y, model.predict(X))
    
    # обучать модель можно также с помощью кросс-валидации
    # применим  cross validation с тем же количеством фолдов
    score = cross_val_score(model, X, y, cv=cv, scoring="f1", n_jobs=-1).mean()

    # метрику необходимо минимизировать, поэтому ставим знак минус
    return -score

# %%
# начинаем подбор гиперпараметров
# %time

trials = Trials() # используется для логирования результатов

best=fmin(hyperopt_rf, # наша функция 
          space=space, # пространство гиперпараметров
          algo=tpe.suggest, # алгоритм оптимизации, установлен по умолчанию, задавать необязательно
          max_evals=50, # максимальное количество итераций
          trials=trials, # логирование результатов
          #rstate=np.random.RandomState(random_state)# фиксируем для повторяемости результата
          rstate=np.random.default_rng(random_state)
         )
print("Наилучшие значения гиперпараметров max_depth = {}, min_samples_leaf = {}, criterion = {}".format(best['max_depth'], best['min_samples_leaf'], criterion_list[best['criterion']]))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 100%|██████████| 50/50 [00:45<00:00,  1.11trial/s, best loss: -0.7921147732439783]
# Наилучшие значения гиперпараметров max_depth = 6.0, min_samples_leaf = 66.0, criterion = gini

# %%
# рассчитаем точность для тестовой выборки
model = tree.DecisionTreeClassifier(
    random_state=random_state, 
    min_samples_leaf=int(best['min_samples_leaf']),
    max_depth=int(best['max_depth']),
    criterion = criterion_list[best['criterion']]
)
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
print('f1_score на обучающем наборе: {:.2f}'.format(metrics.f1_score(y_train, y_train_pred)))
print("accuracy на тестовом наборе: {:.2f}".format(model.score(X_test, y_test)))
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# f1_score на обучающем наборе: 0.81
# accuracy на тестовом наборе: 0.73
# f1_score на тестовом наборе: 0.76

# %% [markdown]
# ## 4.1 optuna + LogisticRegression

# %%
import optuna

# %%
def optuna_rf(trial):
  # задаем пространства поиска гиперпараметров
  penalty = trial.suggest_categorical('penalty', ['l2', 'none'])
  solver = trial.suggest_categorical('solver', ['lbfgs', 'sag'])
  C = trial.suggest_float('C', 0.01, 1, step=0.1)
  
  # создаем модель
  model = linear_model.LogisticRegression(C=C,
                                          penalty=penalty,
                                          solver=solver, 
                                          random_state=42, max_iter=50)
  # обучаем модель
  model.fit(X_train, y_train)
  #score = metrics.f1_score(y_train, model.predict(X_train))
  score = cross_val_score(model, X, y, cv=5, scoring="f1", n_jobs=-1).mean()

  return score

# %%
# %%time
# cоздаем объект исследования
# можем напрямую указать, что нам необходимо максимизировать метрику direction="maximize"
study = optuna.create_study(study_name="LogisticRegression", direction="maximize")
# ищем лучшую комбинацию гиперпараметров n_trials раз
study.optimize(optuna_rf, n_trials=50)
# Out:
# [I 2022-10-31 01:12:46,415] A new study created in memory with name: LogisticRegression
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:12:48,287] Trial 0 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:12:49,742] Trial 1 finished with value: 0.7768367621106458 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.41000000000000003}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:12:50,926] Trial 2 finished with value: 0.7604610029817153 and parameters: {'penalty': 'none', 'solver': 'lbfgs', 'C': 0.81}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:12:55,238] Trial 3 finished with value: 0.7838901806138469 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:12:59,551] Trial 4 finished with value: 0.7794239428980531 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.31000000000000005}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:03,880] Trial 5 finished with value: 0.7757525816757611 and parameters: {'penalty': 'none', 'solver': 'sag', 'C': 0.91}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:05,089] Trial 6 finished with value: 0.7768367621106458 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.41000000000000003}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:09,387] Trial 7 finished with value: 0.7757525816757611 and parameters: {'penalty': 'none', 'solver': 'sag', 'C': 0.51}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:10,591] Trial 8 finished with value: 0.7604610029817153 and parameters: {'penalty': 'none', 'solver': 'lbfgs', 'C': 0.51}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:14,909] Trial 9 finished with value: 0.7797412530375907 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:16,124] Trial 10 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:20,408] Trial 11 finished with value: 0.7838901806138469 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:21,639] Trial 12 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:22,877] Trial 13 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:24,090] Trial 14 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:25,303] Trial 15 finished with value: 0.7757829861122022 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.7100000000000001}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:26,501] Trial 16 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:27,716] Trial 17 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:28,939] Trial 18 finished with value: 0.7604610029817153 and parameters: {'penalty': 'none', 'solver': 'lbfgs', 'C': 0.6100000000000001}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:30,151] Trial 19 finished with value: 0.7789801573520014 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.31000000000000005}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:31,353] Trial 20 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:32,599] Trial 21 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:33,832] Trial 22 finished with value: 0.7789801573520014 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.31000000000000005}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:35,058] Trial 23 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:36,262] Trial 24 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:37,495] Trial 25 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:38,708] Trial 26 finished with value: 0.7604610029817153 and parameters: {'penalty': 'none', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:39,926] Trial 27 finished with value: 0.7789801573520014 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.31000000000000005}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:41,129] Trial 28 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:42,336] Trial 29 finished with value: 0.7768367621106458 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.41000000000000003}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:43,540] Trial 30 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:44,733] Trial 31 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:45,942] Trial 32 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:47,143] Trial 33 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:48,356] Trial 34 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:52,691] Trial 35 finished with value: 0.7757525816757611 and parameters: {'penalty': 'none', 'solver': 'sag', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:53,901] Trial 36 finished with value: 0.7789801573520014 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.31000000000000005}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:13:58,233] Trial 37 finished with value: 0.779883121143641 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.41000000000000003}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:13:59,438] Trial 38 finished with value: 0.7604610029817153 and parameters: {'penalty': 'none', 'solver': 'lbfgs', 'C': 0.91}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:14:03,812] Trial 39 finished with value: 0.7838901806138469 and parameters: {'penalty': 'l2', 'solver': 'sag', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:05,087] Trial 40 finished with value: 0.7760181931839556 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.81}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:06,288] Trial 41 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:07,495] Trial 42 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:08,694] Trial 43 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:09,900] Trial 44 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:11,098] Trial 45 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:1113: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2022-10-31 01:14:15,390] Trial 46 finished with value: 0.7757525816757611 and parameters: {'penalty': 'none', 'solver': 'sag', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:16,617] Trial 47 finished with value: 0.7831048987444514 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.01}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:17,810] Trial 48 finished with value: 0.7851506004638328 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}. Best is trial 0 with value: 0.7851506004638328.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.01, 1] and step=0.1, but the range is not divisible by `step`. It will be replaced by [0.01, 0.91].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [I 2022-10-31 01:14:19,032] Trial 49 finished with value: 0.7790537647090428 and parameters: {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.21000000000000002}. Best is trial 0 with value: 0.7851506004638328.
# CPU times: total: 50.2 s
# Wall time: 1min 32s

# %%
# выводим результаты на обучающей выборке
print("Наилучшие значения гиперпараметров {}".format(study.best_params))
# Out:
# Наилучшие значения гиперпараметров {'penalty': 'l2', 'solver': 'lbfgs', 'C': 0.11}

# %%
# рассчитаем точность для тестовой выборки
model = linear_model.LogisticRegression(**study.best_params, random_state=random_state)
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
print("accuracy на тестовом наборе: {:.2f}".format(model.score(X_test, y_test)))
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# accuracy на тестовом наборе: 0.76
# f1_score на тестовом наборе: 0.79
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## 4.2 optuna + DecisionTreeClassifier

# %%
def optuna_rf(trial):
  # задаем пространства поиска гиперпараметров
  criterion = trial.suggest_categorical('criterion', ['entropy','gini'])
  max_depth = trial.suggest_int('max_depth', 1, 30, 2)
  min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 100, 3)
  
  # создаем модель
  model = tree.DecisionTreeClassifier(max_depth=max_depth,
                                      min_samples_leaf=min_samples_leaf,
                                      criterion=criterion, 
                                      random_state=random_state)
  # обучаем модель
  model.fit(X_train, y_train)
  #score = metrics.f1_score(y_train, model.predict(X_train))
  score = cross_val_score(model, X, y, cv=5, scoring="f1", n_jobs=-1).mean()

  return score

# %%
# %%time
# cоздаем объект исследования
# можем напрямую указать, что нам необходимо максимизировать метрику direction="maximize"
study = optuna.create_study(study_name="DecisionTreeClassifier", direction="maximize")
# ищем лучшую комбинацию гиперпараметров n_trials раз
study.optimize(optuna_rf, n_trials=50)
# Out:
# [I 2022-10-31 01:14:54,577] A new study created in memory with name: DecisionTreeClassifier
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:14:55,558] Trial 0 finished with value: 0.7776521507139219 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_leaf': 68}. Best is trial 0 with value: 0.7776521507139219.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:14:56,763] Trial 1 finished with value: 0.7631478733058498 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 20}. Best is trial 0 with value: 0.7776521507139219.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:14:57,876] Trial 2 finished with value: 0.7767363263268666 and parameters: {'criterion': 'entropy', 'max_depth': 7, 'min_samples_leaf': 11}. Best is trial 0 with value: 0.7776521507139219.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:14:58,769] Trial 3 finished with value: 0.7826231441576148 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 95}. Best is trial 3 with value: 0.7826231441576148.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:14:59,743] Trial 4 finished with value: 0.7737427121167354 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_leaf': 80}. Best is trial 3 with value: 0.7826231441576148.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:00,664] Trial 5 finished with value: 0.7828207411479754 and parameters: {'criterion': 'gini', 'max_depth': 21, 'min_samples_leaf': 86}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:02,160] Trial 6 finished with value: 0.7496859438265808 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_leaf': 8}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:03,226] Trial 7 finished with value: 0.7725329244717976 and parameters: {'criterion': 'gini', 'max_depth': 29, 'min_samples_leaf': 53}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:04,523] Trial 8 finished with value: 0.7795891588130546 and parameters: {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 11}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:05,465] Trial 9 finished with value: 0.7761691709236386 and parameters: {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 80}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:06,561] Trial 10 finished with value: 0.7577916342673416 and parameters: {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 41}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:07,471] Trial 11 finished with value: 0.7809941162284064 and parameters: {'criterion': 'gini', 'max_depth': 21, 'min_samples_leaf': 92}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:08,366] Trial 12 finished with value: 0.7826231441576148 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 95}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:08,918] Trial 13 finished with value: 0.7522687790497345 and parameters: {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 98}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:09,882] Trial 14 finished with value: 0.7776521507139219 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_leaf': 68}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:10,826] Trial 15 finished with value: 0.7761691709236386 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 80}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:11,856] Trial 16 finished with value: 0.7725329244717976 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 53}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:12,815] Trial 17 finished with value: 0.7776521507139219 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 68}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:13,964] Trial 18 finished with value: 0.7561811753883129 and parameters: {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 38}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:14,667] Trial 19 finished with value: 0.7788211594911016 and parameters: {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 86}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:15,636] Trial 20 finished with value: 0.7813583928920657 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_leaf': 65}. Best is trial 5 with value: 0.7828207411479754.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:16,525] Trial 21 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:17,435] Trial 22 finished with value: 0.7789236609978168 and parameters: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 89}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:18,322] Trial 23 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:19,249] Trial 24 finished with value: 0.7814264787547465 and parameters: {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 83}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:20,214] Trial 25 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:21,146] Trial 26 finished with value: 0.7829523148895656 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:22,093] Trial 27 finished with value: 0.7732264979238697 and parameters: {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 74}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:23,082] Trial 28 finished with value: 0.7791091497096655 and parameters: {'criterion': 'gini', 'max_depth': 23, 'min_samples_leaf': 59}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:24,177] Trial 29 finished with value: 0.7577916342673416 and parameters: {'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 41}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:25,126] Trial 30 finished with value: 0.7732264979238697 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_leaf': 74}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:26,059] Trial 31 finished with value: 0.7829523148895656 and parameters: {'criterion': 'entropy', 'max_depth': 25, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:26,997] Trial 32 finished with value: 0.7786062229103868 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_leaf': 92}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:27,924] Trial 33 finished with value: 0.7829523148895656 and parameters: {'criterion': 'entropy', 'max_depth': 27, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:28,876] Trial 34 finished with value: 0.7765357676797974 and parameters: {'criterion': 'entropy', 'max_depth': 17, 'min_samples_leaf': 89}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:30,095] Trial 35 finished with value: 0.7536328494995568 and parameters: {'criterion': 'entropy', 'max_depth': 27, 'min_samples_leaf': 29}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:31,038] Trial 36 finished with value: 0.7786062229103868 and parameters: {'criterion': 'entropy', 'max_depth': 29, 'min_samples_leaf': 92}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:32,031] Trial 37 finished with value: 0.7641295446736335 and parameters: {'criterion': 'entropy', 'max_depth': 21, 'min_samples_leaf': 74}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:32,978] Trial 38 finished with value: 0.7776913659510066 and parameters: {'criterion': 'entropy', 'max_depth': 23, 'min_samples_leaf': 86}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:33,866] Trial 39 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:34,822] Trial 40 finished with value: 0.7720533710531727 and parameters: {'criterion': 'gini', 'max_depth': 13, 'min_samples_leaf': 77}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:35,720] Trial 41 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:36,632] Trial 42 finished with value: 0.7809941162284064 and parameters: {'criterion': 'gini', 'max_depth': 29, 'min_samples_leaf': 92}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:37,547] Trial 43 finished with value: 0.7828207411479754 and parameters: {'criterion': 'gini', 'max_depth': 27, 'min_samples_leaf': 86}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:38,436] Trial 44 finished with value: 0.7826231441576148 and parameters: {'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 95}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:39,325] Trial 45 finished with value: 0.7847229621173162 and parameters: {'criterion': 'gini', 'max_depth': 19, 'min_samples_leaf': 98}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:40,245] Trial 46 finished with value: 0.7814264787547465 and parameters: {'criterion': 'gini', 'max_depth': 17, 'min_samples_leaf': 83}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:41,150] Trial 47 finished with value: 0.7809941162284064 and parameters: {'criterion': 'gini', 'max_depth': 21, 'min_samples_leaf': 92}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:42,057] Trial 48 finished with value: 0.7789236609978168 and parameters: {'criterion': 'gini', 'max_depth': 29, 'min_samples_leaf': 89}. Best is trial 21 with value: 0.7847229621173162.
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [1, 30] and step=2, but the range is not divisible by `step`. It will be replaced by [1, 29].
#   warnings.warn(
# c:\Users\AL\AppData\Local\Programs\Python\Python38\lib\site-packages\optuna\distributions.py:683: UserWarning: The distribution is specified by [5, 100] and step=3, but the range is not divisible by `step`. It will be replaced by [5, 98].
#   warnings.warn(
# [I 2022-10-31 01:15:42,950] Trial 49 finished with value: 0.7826231441576148 and parameters: {'criterion': 'gini', 'max_depth': 11, 'min_samples_leaf': 95}. Best is trial 21 with value: 0.7847229621173162.
# CPU times: total: 15 s
# Wall time: 48.4 s

# %%
# выводим результаты на обучающей выборке
print("Наилучшие значения гиперпараметров {}".format(study.best_params))
# Out:
# Наилучшие значения гиперпараметров {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 98}

# %%
# рассчитаем точность для тестовой выборки
model = tree.DecisionTreeClassifier(**study.best_params, random_state=42)
model.fit(X_train, y_train)
y_train_pred = model.predict(X_train)
print("accuracy на тестовом наборе: {:.2f}".format(model.score(X_test, y_test)))
y_test_pred = model.predict(X_test)
print('f1_score на тестовом наборе: {:.2f}'.format(metrics.f1_score(y_test, y_test_pred)))
# Out:
# accuracy на тестовом наборе: 0.74
# f1_score на тестовом наборе: 0.78
